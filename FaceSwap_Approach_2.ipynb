# %% [markdown]
# <a href="https://colab.research.google.com/github/rohandawar/-daysforcoding/blob/main/FaceSwap_Approach_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, I am trying the faceswap via haarcascade

# %%
# Import libs
import cv2
import numpy as np
from PIL import Image
import requests

# %%
image1 = Image.open(requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSx8Pu1tW1uCiZPfj9K1EL6uHxbg3bOKO9XkA&usqp=CAU', stream=True).raw)
image1= image1.resize((300,300))
img1_array = np.array(image1)
image1
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FC9F4D534F0>

# %%
# Reading the Destination Image
image2 = Image.open(requests.get('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTYX1dyl9INRo5cbvDeTILRcZVzfcMsCsE0kg&usqp=CAU', stream=True).raw)
image2 = image2.resize((300,300))
img2_array = np.array(image2)
image2
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FC9F4D513C0>

# %%
# Define a face cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

# Detect Face#1
faces1 = face_cascade.detectMultiScale(img1_array,1.1,1)

# Detect Face#2
faces2 = face_cascade.detectMultiScale(img2_array,1.1,1)

# %%
# # Ensure that we have found faces 
# if len(faces1) >0 and len(faces2) >0:
  
#   # Select the first face
#   x1,y1,w1,h1 = faces1[0]
#   x2,y2,w2,h2 = faces2[0]

#   # Extract the ROI(Region of INtrest)
#   face1_roi = img1_array[y1:y1+h1, x1:x1+w1]
#   face2_roi = img2_array[y2:y2+h2, x2:x2+w2]

#   # Resize the ROI to match
#   face2_roi_resized = cv2.resize(face2_roi, (w1,h1))

#   # Swap the faces
#   img1_array[y1:y1+h1, x1:x1+w1] = face2_roi_resized
#   img2_array[y2:y2+h2, x2:x2+w2] = face1_roi

#   # Display
#   cv2.imshow('Face Swap 1 ', image1)
#   cv2.imshow('Face Swap 2 ', image2)
# else:
#   Print('Unable to detectt faces in one or both images.')
